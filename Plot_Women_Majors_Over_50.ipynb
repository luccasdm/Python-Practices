# %% [markdown]
# <a href="https://colab.research.google.com/github/luccasdm/Python-Practices/blob/main/Plot_Women_Majors_Over_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# %matplotlib inline
direct_link = 'http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv'
women_majors = pd.read_csv(direct_link)

print(women_majors.info())
women_majors.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           42 non-null     int64
#  1   Agriculture                    42 non-null     float64
#  2   Architecture                   42 non-null     float64
#  3   Art and Performance            42 non-null     float64
#  4   Biology                        42 non-null     float64
#  5   Business                       42 non-null     float64
#  6   Communications and Journalism  42 non-null     float64
#  7   Computer Science               42 non-null     float64
#  8   Education                      42 non-null     float64
#  9   Engineering                    42 non-null     float64
#  10  English                        42 non-null     float64
#  11  Foreign Languages              42 non-null     float64
#  12  Health Professions             42 non-null     float64
#  13  Math and Statistics            42 non-null     float64
#  14  Physical Sciences              42 non-null     float64
#  15  Psychology                     42 non-null     float64
#  16  Public Administration          42 non-null     float64
#  17  Social Sciences and History    42 non-null     float64
# dtypes: float64(17), int64(1)
# memory usage: 6.0 KB
# None
#    Year  Agriculture  ...  Public Administration  Social Sciences and History
# 0  1970     4.229798  ...                   68.4                         36.8
# 1  1971     5.452797  ...                   65.5                         36.2
# 2  1972     7.420710  ...                   62.6                         36.1
# 3  1973     9.653602  ...                   64.3                         36.4
# 4  1974    14.074623  ...                   66.1                         37.3
#
# [5 rows x 18 columns]

# %%
women_majors = women_majors.rename(columns={'Year':'Ano',
                                            'Art and Performance':'Arte e Performance',
                                            'Education':'Educação',
                                            'English':'Inglês',
                                            'Foreign Languages':'Linguagens Estrangeiras',
                                            'Health Professions':'Profissionais de Saúde',
                                            'Public Administration':'Administração Pública'
                                            })

# %%
# Acima de 50%
over_50 = women_majors.loc[0, (women_majors.loc[0]>50) & (women_majors.loc[0]<100)]
over_50
# Out:
# Arte e Performance         59.700000
# Educação                   74.535328
# Inglês                     65.570923
# Linguagens Estrangeiras    73.800000
# Profissionais de Saúde     77.100000
# Administração Pública      68.400000
# Name: 0, dtype: float64

# %%
over_50_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8))
print('Type:', type(over_50_graph))
# Out:
# Type: <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
# Importar styles do matplotlib
import matplotlib.style as style
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
style.use('fivethirtyeight')
women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8))

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 55, color = 'black', linewidth = 1.3, alpha = .70)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 55, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 55, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 55, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = 49.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = 50,
               s ='   Nome:                                                                                                          Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 55, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = 49.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = 50,
               s ='   Nome:                                                                                                          Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# Acrescentar título e subtítulo
fte_graph.text(x = 1966.65, y = 94, s = "                  A diferença de gênero é transitória  ",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 90, 
               s = '     Porcentegens de títulos conferidos a mulheres de 1970 a 2011 nos Estados Unidos \n               para casos extremos com porcentagens menores a 20% em 1970',
              fontsize = 19, alpha = .85)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 55, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = 49.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = 50,
               s ='   Nome:                                                                                                          Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# Acrescentar título e subtítulo
fte_graph.text(x = 1966.65, y = 94, s = "                  A diferença de gênero é transitória  ",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 90, 
               s = '     Porcentegens de títulos conferidos a mulheres de 1970 a 2011 nos Estados Unidos \n               para casos extremos com porcentagens menores a 20% em 1970',
              fontsize = 19, alpha = .85)

# Add colored labels
fte_graph.text(x = 2012, y = 80, s = 'Agricultura', color = colors[0], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')

# %%
# cores 
colors = [[0,0,0], 
          [230/255,159/255,0], 
          [86/255,180/255,233/255], 
          [0,158/255,115/255], 
          [213/255,94/255,0], 
          [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Ano', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '55%  ','60%  ', '65%  ', '70%  ', '75%  ', '80%  ', '85%  ','90%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 60, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(True)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = 52.55,
               s = '_____________________________________________________________________________________________________________________________',
               color = 'grey', weight = 'bold', alpha = .70)
fte_graph.text(x = 1966.1, y = 53,
               s ='   Nome: Luccas Del Mastro Garcia           RA: 2101645                                      Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'red', alpha = .7)

# Acrescentar título e subtítulo
fte_graph.text(x = 1966.65, y = 94, s = "                  A diferença de gênero é transitória  ",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 90, 
               s = '     Porcentegens de títulos conferidos a mulheres de 1970 a 2011 nos Estados Unidos \n               para casos extremos com porcentagens maiores de 50% em 1970',
              fontsize = 19, alpha = .85)

# Add colored labels
fte_graph.text(x = 2012, y = 61, s = 'Arte e Performance', color = colors[0], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2012, y = 79, s = 'Educação', color = colors[1], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2012, y = 68, s = 'Inglês', color = colors[2], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2012, y = 70, s = 'Linguagens Estrangeiras', color = colors[3], weight = 'bold', rotation = 0,backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2012, y = 84, s = 'Profissionais de Saúde', color = colors[4], weight = 'bold',rotation=0, backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2012, y = 82, s = 'Administração Pública', color = colors[5], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')
# Out:
# The tick labels of the y-axis: [55. 60. 65. 70. 75. 80. 85. 90.]
# Text(2012, 82, 'Administração Pública')
